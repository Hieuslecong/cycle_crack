# %%
# !git clone https://github.com/Hieuslecong/cycle_crack.git
# Out:
# Cloning into 'cycle_crack'...
# remote: Enumerating objects: 49, done.
# remote: Counting objects: 100% (49/49), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 49 (delta 10), reused 48 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (49/49), 87.62 KiB | 1.86 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/cycle_crack/
# Out:
# /content/cycle_crack

# %%
# !cp -r /content/drive/MyDrive/data/noncrack/ /content/cycle_crack/data/
# Out:
# ^C

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd" -O data_downloaded && rm -rf /tmp/cookies.txt
# Out:
# --2026-04-19 18:01:12--  https://docs.google.com/uc?export=download&confirm=&id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd
# Resolving docs.google.com (docs.google.com)... 108.177.119.138, 108.177.119.101, 108.177.119.102, ...
# Connecting to docs.google.com (docs.google.com)|108.177.119.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd&export=download [following]
# --2026-04-19 18:01:12--  https://drive.usercontent.google.com/download?id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2422 (2.4K) [text/html]
# Saving to: ‘data_downloaded’
#
# ...

# %%
# !gdown 1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd
# From (redirected): https://drive.google.com/uc?id=1k82cNq_4TH2Yl9r3k8VKpFslUJI2gVDd&confirm=t&uuid=10b82ea4-5437-4f53-acb6-b2458a33958d
# To: /content/cycle_crack/data.tar.gz
# 100% 3.20G/3.20G [00:17<00:00, 184MB/s]

# %%
# !tar -xzvf data.tar.gz
# Out:
# data/
# data/crack/
# data/crack/Stone331_950.png
# data/crack/TopoDS_KB0739_41_2304_512.png
# data/crack/BCL_c3301.png
# data/crack/DeepCrack_11231-9.png
# data/crack/TopoDS_SFR_1955_56_1024_1024.png
# data/crack/Stone331_767.png
# data/crack/Stone331_1161.png
# data/crack/Khanh11k_Rissbilder_for_Florian_9S6A2863_312_1094_3025_3361.png
# data/crack/Stone331_1271.png
# data/crack/AEL_Im_GT_AIGLE_RN_C19aor.png
# data/crack/CrSpEE_spalling, cracking and exposed reinforcement12.png
# data/crack/CRACK500_20160328_154339.png
# data/crack/TopoDS_FBR_P1000026_56_2816_768.png
# data/crack/Stone331_1084.png
# data/crack/AEL_Im_GT_AIGLE_RN_F01bor.png
# data/crack/BCL_s1218.png
# data/crack/BCL_s1328.png
# data/crack/DeepCrack_11296-13.png
# data/crack/Stone331_1121.png
# data/crack/DeepCrack_11296-3.png
# data/crack/CRACK500_20160329_104111.png
# data/crack/DIC_SVS_2_LS30_to_LS31_RS4_0000_0_171_2304_2304.png
# data/crack/BCL_c3565.png
# data/crack/CFD_067.png
# data/crack/BCL_s1613.png
# ...

# %%
# !python train_v3.py --data_root /content/drive/MyDrive/colab_pro_hieus --epochs 100 --batch_size 64
# Out:
# 2026-04-20 13:32:05.306675: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 13:32:05.325210: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776691925.347836   14704 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776691925.355328   14704 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train.py --config config.yaml
# Out:
# 2026-04-20 08:59:45.347067: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-20 08:59:45.365583: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776675585.388669   17020 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776675585.396093   17020 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !python train_v3.py
# Out:
# python3: can't open file '/content/cycle_crack/train_v3.py': [Errno 2] No such file or directory
